# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %%
Tweets_df = pd.read_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Foursquare_Osaka/merged_Tweet_place.csv')
# Out:
# /tmp/ipykernel_30939/808643800.py:1: DtypeWarning: Columns (0,1,3,4,5,6,7,8,9,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   Tweets_df = pd.read_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Foursquare_Osaka/merged_Tweet_place.csv')

# %%
user_name_list = Tweets_df['user_name'].unique()

# %%
user_sequence = Tweets_df[Tweets_df['user_name']==user_name_list[10]]
locs_sequence = []
for index, r in user_sequence.iterrows():
    locs_sequence.append([r.UserPlase_latitude,r.UserPlase_longitude])

m = folium.Map(location=[35.6, 139.7], zoom_start=7.0)
folium.PolyLine(locations=locs_sequence).add_to(m)
folium.Marker(locs_sequence[0], popup='end').add_to(m)
folium.Marker(locs_sequence[-1], popup='start', icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2916de21bce97aee2211e671c1bdee2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2916de21bce97aee2211e671c1bdee2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2916de21bce97aee2211e671c1bdee2f = L.map(
#                 &quot;map_2916de21bce97aee2211e671c1bdee2f&quot;,
#                 {
#                     center: [35.6, 139.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7.0,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d559691e1a23649a1eeda51944c23be9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2916de21bce97aee2211e671c1bdee2f);
#
#
#             var poly_line_5828a52d4a61f5555d70ff99f443f1dd = L.polyline(
#                 [[34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.618703, 133.739451], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.417377, 133.602449], [34.263329, 133.795625], [34.263329, 133.795625], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.6285079964302, 135.166249999236], [34.62850799643 ...

# %%
user_sequence = Tweets_df[Tweets_df['user_name']==user_name_list[100]]
locs_sequence = []
for index, r in user_sequence.iterrows():
    locs_sequence.append([r.UserPlase_latitude,r.UserPlase_longitude])


m = folium.Map(location=[35.6, 139.7], zoom_start=7.0)
marker_cluster = MarkerCluster().add_to(m)
for i in range(0,len(locs_sequence)):
    folium.Marker(locs_sequence[i], popup=r.text).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f3f21a44a86a227aa43491c6faef75c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f3f21a44a86a227aa43491c6faef75c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1f3f21a44a86a227aa43491c6faef75c = L.map(
#                 &quot;map_1f3f21a44a86a227aa43491c6faef75c&quot;,
#                 {
#                     center: [35.6, 139.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7.0,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdaea16c64cc3ef988bcf15b362bc082 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f3f21a44a86a227aa43491c6faef75c);
#
#
#             var marker_cluster_3a6e294df75a5c1109b3d30573b828ca = L.markerClusterGroup(
#                 {}
#             );
#             map_1f3f21a44a86a227aa43491c6faef75c.addLayer(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);
#
#
#             var marker_a7319d4f6ce986d2d0288959eb861172 = L.marker(
#                 [34.618703, 133.739451],
#                 {}
#             ).addTo(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);
#
#
#         var popup_1fef5ba9b71366e32a29f7729cf1ea12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7ef064f3da777ef782c0459627a05472 = $(`&lt;div id=&quot;html_7ef064f3da777ef782c0459627a05472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ｲﾏｺｺ! 鹿児島県日置市日吉町日置２８７７ #imacoconow [イマココくん Android] https://t.co/fORcoEF2Tq&lt;/div&gt;`)[0];
#             popup_1fef5ba9b71366e32a29f7729cf1ea12.setContent(html_7ef064f3da777ef782c0459627a05472);
#
#
#         marker_a7319d4f6ce986d2d0288959eb861172.bindPopup(popup_1fef5ba9b71366e32a29f7729cf1ea12)
#         ;
#
#
#
#
#             var marker_2a1e8ca83ec3bdbc64c04e2867cdf702 = L.marker(
#                 [34.618703, 133.739451],
#                 {}
#             ).addTo(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);
#
#
#         var popup_a00d0a50fa4c9ce3318b2b22ec582269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5dbefb1d222597f5ff2e1f4be78e69aa = $(`&lt;div id=&quot;html_5dbefb1d222597f5ff2e1f4be78e69aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ｲﾏｺｺ! 鹿児島県日置市日吉町日置２８７７ #imacoconow [イマココくん Android] https://t.co/fORcoEF2Tq&lt;/div&gt;`)[0];
#             popup_a00d0a50fa4c9ce3318b2b22ec582269.setContent(html_5dbefb1d222597f5ff2e1f4be78e69aa);
#
#
#         marker_2a1e8ca83ec3bdbc64c04e2867cdf702.bindPopup(popup_a00d0a50fa4c9ce3318b2b22ec582269)
#         ;
#
#
#
#
#             var marker_35302c56f5201e68777264fe70b16e60 = L.marker(
#                 [33.901953, 132.808019],
#                 {}
#             ).addTo(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);
#
#
#         var popup_4956545131c98c693ee295088c00aa38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4142470b6d1da692b50fab06942e036b = $(`&lt;div id=&quot;html_4142470b6d1da692b50fab06942e036b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ｲﾏｺｺ! 鹿児島県日置市日吉町日置２８７７ #imacoconow [イマココくん Android] https://t.co/fORcoEF2Tq&lt;/div&gt;`)[0];
#             popup_4956545131c98c693ee295088c00aa38.setContent(html_4142470b6d1da692b50fab06942e036b);
#
#
#         marker_35302c56f5201e68777264fe70b16e60.bindPopup(popup_4956545131c98c693ee295088c00aa38)
#         ;
#
#
#
#
#             var marker_67495e4fdb50aeb6a2ba42326202684d = L.marker(
#                 [33.901953, 132.808019],
#                 {}
#             ).addTo(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);
#
#
#         var popup_7763bdef0e765673615bee17a71f3b7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_16bdac8a8c4eb4972f90e5f7275dc3ce = $(`&lt;div id=&quot;html_16bdac8a8c4eb4972f90e5f7275dc3ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ｲﾏｺｺ! 鹿児島県日置市日吉町日置２８７７ #imacoconow [イマココくん Android] https://t.co/fORcoEF2Tq&lt;/div&gt;`)[0];
#             popup_7763bdef0e765673615bee17a71f3b7a.setContent(html_16bdac8a8c4eb4972f90e5f7275dc3ce);
#
#
#         marker_67495e4fdb50aeb6a2ba42326202684d.bindPopup(popup_7763bdef0e765673615bee17a71f3b7a)
#         ;
#
#
#
#
#             var marker_868e44606d0f08b05bb6286386e51e7b = L.marker(
#                 [33.901953, 132.808019],
#                 {}
#             ).addTo(marker_cluster_3a6e294df75a5c1109b3d30573b828ca);

# %%
user_sequence
# Out:
#            index local_id      tweet_id                 timestamp   user_id  \
# 1235        1235      219  1.351598e+18  2021-01-19T18:29:51.000Z  14361499
# 1236        1236     3378  1.084349e+18  2019-01-13T07:17:57.000Z  14361499
# 18983      18983      257  1.343020e+18  2020-12-27T02:25:33.000Z  14361499
# 18984      18984      258  1.343009e+18  2020-12-27T01:42:12.000Z  14361499
# 18985      18985      259  1.343000e+18  2020-12-27T01:05:27.000Z  14361499
# ...          ...      ...           ...                       ...       ...
# 3806568  3390436     2842  1.123431e+18  2019-05-01T03:35:57.000Z  14361499
# 3806569  3390437     2843  1.123423e+18  2019-05-01T03:05:45.000Z  14361499
# 3806632  3390500     2851  1.123385e+18  2019-05-01T00:35:23.000Z  14361499
# 3806633  3390501     2853  1.123380e+18  2019-05-01T00:12:34.000Z  14361499
# 3806634  3390502     2854  1.123378e+18  2019-05-01T00:05:21.000Z  14361499
#
#           user_name user_screenname            source  \
# 1235     じゃこう/麝香鼠車車          jyakou  Foursquare Swarm
