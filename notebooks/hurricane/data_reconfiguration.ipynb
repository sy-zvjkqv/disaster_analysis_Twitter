# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import spacy
# Out:
# 2022-10-05 15:33:50.990670: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-10-05 15:33:50.990706: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
merged_Tweets_df = pd.read_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/merged_data.csv')

# %%
estimated_df = pd.read_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/estimated_test.csv')

# %%
time_list =  merged_Tweets_df['CreateTime']
y_list = []
mm_list = []
d_list = []
h_list = []
min_list = []
for time in time_list:
    y_list.append(time[0:4])
    mm_list.append(time[5:7])
    d_list.append(time[8:10])
    h_list.append(time[11:13])
    min_list.append(time[14:16])

# %%
ymd = []
for i in range(0,len(y_list)):
    merge = y_list[i]+mm_list[i]+d_list[i]
    ymd.append(merge)

# %%
ymdh = []
for i in range(0,len(y_list)):
    merge = y_list[i]+mm_list[i]+d_list[i]+h_list[i]
    ymdh.append(merge)

# %%
len(ymd)
# Out:
# 346293

# %%
time_df = pd.DataFrame(
    {'year':y_list,
    'month':mm_list,
    'day':d_list,
    'hour':h_list,
    'minutes':min_list,
    'ymd':ymd,
    'ymdh':ymdh
    }
)

# %%
time_line = pd.concat([merged_Tweets_df, time_df], axis=1)

# %%
time_line.to_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/split_time.csv',index=False)

# %%
time_line
# Out:
#                  Unnamed: 0 Keyword                CreateTime  \
# 0       1178548273662922752      強風  2019-09-30T05:52:59.000Z
# 1       1178060001467781120      強風  2019-09-28T21:32:46.000Z
# 2       1170136271412285441      強風  2019-09-07T00:46:41.000Z
# 3       1169374026277380096      強風  2019-09-04T22:17:48.000Z
# 4       1169145697930756096      強風  2019-09-04T07:10:30.000Z
# ...                     ...     ...                       ...
# 346288  1182513347163348993      台風  2019-10-11T04:28:46.000Z
# 346289  1162302789977927681      台風  2019-08-16T09:59:14.000Z
# 346290  1161964973423132674      台風  2019-08-15T11:36:52.000Z
# 346291  1162211108645560320      台風  2019-08-16T03:54:55.000Z
# 346292  1176142968119599104      台風  2019-09-23T14:35:09.000Z
#
#                                                      Text  \
# 0       竹富島はなかなかの暴風雨ですが、まだ強風域です。本番は今夜の暴風域です…。\n(￣□￣;)!...
# 1       おはようございます🤙#竹富島 は晴れのち雨30%予報で、今夜には強風圏内です。満潮は7:14...
# 2       おはようございます。\n\n台風空け 気温低めで 接近しても ほとんど動かない。夜明けの気温...
# 3       おはようございます(*^ー^)ノ♪#竹富島 は #台風13号 Linglingの強風域に居ま...
# 4       台風13号Linglingの暴風域が竹富島を避ける様に回り込む様な経路を取る予報で、コンドイ...
# ...                                                   ...
# 346288      @hito_sj20 ありがとうございます。\n \n台風近付いているから、気をつけてね。
# 346289  【重要】台風接近に伴う八木沢会場の入場禁止について\n\n台風10号の接近に伴い、8月17日...
# 346290  【重要】台風到来に伴う八木沢会場の入場禁止について\n\n台風10号の接近に伴い、8月16日...
# 346291  台風ツーリング楽しい () (@ 峨瓏の滝) https://t.co/4uY1pjfnd8...
# 346292  🌀大型の台風17号は23日に日本海で温帯低気圧に…\n【過去pic】 場所: 日本で最も小さ...
#
#                                               CleanedText      AuthorID  \
# 0       竹富島はなかなかの暴風雨ですが、まだ強風域です。本番は今夜の暴風域です...。 ( ̄□ ̄...  8.116087e+17
# 1       おはようございます🤙 は晴れのち雨30%予報で、今夜には強風圏内です。満潮は7:14と19:...  8.116087e+17
# 2       おはようございます。  台風空け 気温低めで 接近しても ほとんど動かない。夜明けの気温25...  7.771396e+08
# 3       おはようございます(*^ー^)ノ♪ は  Linglingの強風域に居ます。可愛い名前ですが...  8.116087e+17
# 4       台風13号Linglingの暴風域が竹富島を避ける様に回り込む様な経路を取る予報で、コンドイ...  8.116087e+17
# ...                                                   ...           ...
# 346288                   ありがとうございます。   台風近付いているから、気をつけてね。  1.342989e+08
# 346289  【重要】台風接近に伴う八木沢会場の入場禁止について  台風10号の接近に伴い、8月17日につ...  1.143514e+18
# 346290  【重要】台風到来に伴う八木沢会場の入場禁止について  台風10号の接近に伴い、8月16日は八...  1.143514e+18
# 346291                             台風ツーリング楽しい () (@ 峨瓏の滝)  2.917540e+09
# 346292  🌀大型の台風17号は23日に日本海で温帯低気圧に... 【過去pic】 場所: 日本で最も小...  4.717843e+08
#
#                 place_id Prefecture  ConversationID  RetweetCount  ...  \
# 0       88d60b8f4d134b5a    Okinawa    1.178548e+18          12.0  ...
# 1       88d60b8f4d134b5a    Okinawa    1.178060e+18           3.0  ...
# 2       88d60b8f4d134b5a    Okinawa    1.170136e+18           0.0  ...
# 3       88d60b8f4d134b5a    Okinawa    1.169374e+18           1.0  ...
# 4       88d60b8f4d134b5a    Okinawa    1.169146e+18           2.0  ...
# ...                  ...        ...             ...           ...  ...
# 346288  4b7bdf89baf1c83d     Miyagi    1.182456e+18           0.0  ...
# 346289  1170689883e8a3d7      Akita    1.162303e+18           2.0  ...
# 346290  1170689883e8a3d7      Akita    1.161965e+18           2.0  ...
# 346291  16ea2a7e16a8eaf4      Akita    1.162211e+18           0.0  ...
# 346292  3acacd8e9d36d4c2     Aomori    1.176143e+18           1.0  ...
#
#         UserPlase_sub_longitude  UserPlase_sub_latitude  code  year month day  \
# 0                    124.101945               24.477140  3623  2019    09  30
# 1                    124.101945               24.477140  3623  2019    09  28
# 2                    124.101945               24.477140  3623  2019    09  07
# 3                    124.101945               24.477140  3623  2019    09  04
# 4                    124.101945               24.477140  3623  2019    09  04
# ...                         ...                     ...   ...   ...   ...  ..
# 346288               140.888621               38.573335  5740  2019    10  11
# 346289               140.401419               40.091569  5940  2019    08  16
# 346290               140.401419               40.091569  5940  2019    08  15
# 346291               140.356229               40.446629  6040  2019    08  16
# 346292               140.940255               41.468653  6140  2019    09  23
#
#         hour  minutes       ymd        ymdh
# 0         05       52  20190930  2019093005
# 1         21       32  20190928  2019092821
# 2         00       46  20190907  2019090700
# 3         22       17  20190904  2019090422
# 4         07       10  20190904  2019090407
# ...      ...      ...       ...         ...
# 346288    04       28  20191011  2019101104
# 346289    09       59  20190816  2019081609
# 346290    11       36  20190815  2019081511
# 346291    03       54  20190816  2019081603
# 346292    14       35  20190923  2019092314
#
# [346293 rows x 28 columns]
