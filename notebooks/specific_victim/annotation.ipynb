# %%
import pandas as pd

# %%
Tweet_Data = pd.read_csv("/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/rePlace_data_marged.csv")

# %%
samples = Tweet_Data.sample(n=100, random_state=0)

# %%
samples = samples.replace( '\n', '', regex=True)

# %%
samples.to_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/sample.csv')

# %%
samples
# Out:
#                  Unnamed: 0 Keyword                CreateTime  \
# 262417  1182936311629414400      台風  2019-10-12T08:29:29.000Z
# 231896  1183302593365200897      台風  2019-10-13T08:44:57.000Z
# 159111  1145225226583625730       雨  2019-06-30T06:59:05.000Z
# 192841  1171784700727160832       雨  2019-09-11T13:56:58.000Z
# 235231  1174869456259956736      台風  2019-09-20T02:14:41.000Z
# ...                     ...     ...                       ...
# 81200   1170811175740641280       雨  2019-09-08T21:28:31.000Z
# 195839  1151084327863631872       雨  2019-07-16T11:01:04.000Z
# 367172  1172645710656704513      台風  2019-09-13T22:58:18.000Z
# 323436  1182923180790308865      台風  2019-10-12T07:37:18.000Z
# 266516  1162340285210169344      台風  2019-08-16T12:28:13.000Z
#
#                                                      Text  \
# 262417                                     本日台風の為臨時休業します。
# 231896  旧民主党政権が、「無駄遣いだから切れ‼️」と「事業仕分け」と称して建設工事🚧⚠️を止めた八ッ...
# ...

# %%
samples = pd.read_csv('/home/is/shuntaro-o/dev/disaster_analysis_Twitter/data/Hurricane/sample.csv')

# %%
samples['annotation'].sum()
# Out:
# 42
